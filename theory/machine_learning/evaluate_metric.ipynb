# %% [markdown]
# Metric for evaluating classification and regression
# (understanding + computation)
#
# Understand the Metric walkthrough in his website
#
# Confusion Matrix and from confusino matrix, we can compute the accuracy, reason, recall, F1, macro and
#
# Regression, how to do
# Classification, how to
